# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
BASE_DIR = '/home/intern/ai-inacbg'
WORK_DIR = os.path.join(BASE_DIR, 'predict-inacbg')
DATA_DIR = os.path.join(WORK_DIR, 'rawdata-inacbg')

# print('BASE_DIR:', BASE_DIR)
# print('WORK_DIR:', WORK_DIR)
# print('DATA_DIR:', DATA_DIR)

# %%
# !ls -l $DATA_DIR
# Out:
# total 713984
# -rw-rw-r-- 1 intern intern 245233406 Feb 24 21:37 C_inacbg_new.csv
# -rw-rw-r-- 1 intern intern  18637210 Feb 24 21:36 DE_inacbg_new.csv
# -rw-rw-r-- 1 intern intern  16492792 Feb 26 10:00 DE_inacbg_new_edited.csv
# -rw-rw-r-- 1 intern intern 102365110 Feb 24 21:37 D_inacbg_new.csv
# -rw-rw-r-- 1 intern intern  45755761 Feb 24 21:43 inacbg_new.csv
# -rw-rw-r-- 1 intern intern 104012116 Feb 24 21:39 M_inacbg_new.csv
# -rw-rw-r-- 1 intern intern 144157128 Feb 24 21:43 P_inacbg_new.csv
# -rw-rw-r-- 1 intern intern  54428180 Feb 24 21:45 Q_inacbg_new.csv

# %%
# Read CSV
csv_file = 'DE_inacbg_new.csv'
df = pd.read_csv(os.path.join(DATA_DIR, csv_file), sep=";", dtype=str, encoding="utf-8", encoding_errors="replace")
df.head(10)
# Out:
#    ID              Tanggal       RegID                SEPID      INACBG  \
# 0   1  2023-11-28 16:18:39  P231101330  0138R0461123V000083    N-3-15-0
# 1   2  2023-12-02 12:45:25  P231101319  0138R0461123V000011    A-4-14-I
# 2   3  2023-12-02 12:54:52  P231101594  0138R0461123V000042    J-4-16-I
# 3   4  2023-12-02 12:54:52  P231101594  0138R0461123V000042    J-4-16-I
# 4   5  2023-12-02 12:59:21  P231101533  0138R0461123V000036  M-4-17-III
# 5   6  2023-12-02 12:59:21  P231101533  0138R0461123V000036  M-4-17-III
# 6   7  2023-12-02 12:59:21  P231101533  0138R0461123V000036  M-4-17-III
# 7   8  2023-12-02 12:59:21  P231101533  0138R0461123V000036  M-4-17-III
# 8   9  2023-12-04 08:34:31  P231101528  0138R0461123V000035    J-4-16-I
# 9  10  2023-12-04 08:36:00  P231101247  0138R0461123V000006  J-4-15-III
#
#    ICD10  ICD9                                        INACBG_Desc  \
# 0  N18.8   NaN                                  PROSEDUR DIALISIS
# ...

# %%
print(df.info())
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725163 entries, 0 to 725162
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            725163 non-null  object
#  1   Tanggal       725163 non-null  object
#  2   RegID         725162 non-null  object
#  3   SEPID         630056 non-null  object
#  4   INACBG        715463 non-null  object
#  5   ICD10         539024 non-null  object
#  6   ICD9          273310 non-null  object
#  7   INACBG_Desc   714700 non-null  object
#  8   ICD10_Desc    538407 non-null  object
#  9   ICD9_Desc     273310 non-null  object
#  10  JumlahCoding  725162 non-null  object
# dtypes: object(11)
# memory usage: 60.9+ MB
# None
#             ID              Tanggal       RegID   SEPID    INACBG   ICD10  \
# count   725163               725163      725162  630056    715463  539024
# unique  725163               508355      510863  415049       626    4457
# ...

# %% [markdown]
# <!-- Show a rows when SEPID is not NaN -->

# %% [markdown]
# ## **Save dan Read Versi Baru**

# %%
csv_outfile = f'{csv_file[:-4]}_edited.csv'
# save df as csv
df.to_csv(os.path.join(DATA_DIR, csv_outfile), sep=';', index=0)
df = pd.read_csv(os.path.join(DATA_DIR, csv_outfile), delimiter=";", na_values=["NULL"])
print("Successfully saved as", csv_outfile)
df.head(10)
# Out:
# Successfully saved as C_inacbg_new_edited.csv
# /tmp/ipykernel_1912261/1674823532.py:4: DtypeWarning: Columns (6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(DATA_DIR, csv_outfile), delimiter=";", na_values=["NULL"])
#    ID              Tanggal       RegID SEPID INACBG  ICD10 ICD9 INACBG_Desc  \
# 0   1  2016-11-18 16:27:01  P161105288   NaN    NaN    K81  NaN         NaN
# 1   2  2016-11-18 18:55:03  P161104760   NaN    NaN  I67.9  NaN         NaN
# 2   3  2016-11-19 09:47:08  P161104443   NaN    NaN    D24  NaN         NaN
# 3   4  2016-11-19 12:46:31  P161106024   NaN    NaN  M79.9  NaN         NaN
# 4   5  2016-11-19 19:56:01  P161105564   NaN    NaN  I67.9  NaN         NaN
# 5   6  2016-11-19 19:58:48  P161102769   NaN    NaN    I21  NaN         NaN
# 6   7  2016-11-21 14:43:54  P161105011   NaN    NaN  A01.0  NaN         NaN
# 7   8  2016-11-21 16:53:00  P161105561   NaN    NaN  A04.9  NaN         NaN
# ...
