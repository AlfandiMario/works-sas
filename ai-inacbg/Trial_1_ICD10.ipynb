# %%
import pandas as pd
df = pd.read_csv('t_sample.csv', sep=',')

# %%
df.head(100)
# Out:
#     T_SampleID T_SampleCode  \
# 0            1          J40
# 1            2        A02.0
# 2            3        J02.9
# 3            4          K30
# 4            5          R51
# ..         ...          ...
# 95          96          I10
# 96          97          A09
# 97          98          E11
# 98          99          I10
# 99         100          L50
#
#                                          T_SampleName       T_SampleFileName  \
# 0                                 GEA tanpa dehidrasi  regpas_diagnosa_ayani
# 1   Enteritis Akut   PPOK, AKI dd Akut On CKD, Hip...  regpas_diagnosa_ayani
# 2                    Rhinofaringitis akut   Dyspepsia  regpas_diagnosa_ayani
# 3                                           dyspepsia  regpas_diagnosa_ayani
# 4                           Chepalgia, Bronkitis akut  regpas_diagnosa_ayani
# ..                                                ...                    ...
# 95                                    CHF, Neurophaty  regpas_diagnosa_ayani
# ...

# %%
df.tail(10)
# Out:
#          T_SampleID T_SampleCode  \
# 9369011     9603353        D47.4
# 9369012     9603354        R10.4
# 9369013     9603355        J06.9
# 9369014     9603356        M54.5
# 9369015     9603357        R10.4
# 9369016     9603358        R10.4
# 9369017     9603359          S64
# 9369018     9603360        J06.9
# 9369019     9603361        J06.9
# 9369020     9603362        R50.9
#
#                                               T_SampleName  \
# 9369011                                     Myelofibrosis
# 9369012               Abdominal pain suspek cholelithiasis
# 9369013                                 Fever hari 0, ISPA
# 9369014                        Low Back Pain dd Ischialgia
# 9369015  Abdominal Pain, Nausea Vomitus, Diare akut TAN...
# 9369016               Abdominal Pain, Nausea and Vomitus,
# 9369017                     Injury of upper hand, post KLL
# 9369018                                        Cough, ISPA
# ...
